# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishika-S27/OPTIMIZATION-TECHNIQUES/blob/main/OT_prac1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy as sp

# %%
x = sp.symbols('x')
f = x**3-6*x**2+9*x+1
print('Function:')
print(f)
# Out:
# Function:
# x**3 - 6*x**2 + 9*x + 1

# %%
# 1st derivative
f_prime = sp.diff(f, x)
print('\nFirst Derivative:')
print(f_prime)

# Critical points
critical_points = sp.solve(f_prime, x)

#2nd derivative
f_double = sp.diff(f_prime, x)
print('\nCritical Points Analysis:')
for point in critical_points:
    second_value = f_double.subs(x, point)

    if second_value > 0:
        print(f"x = {point}: Local Minimum")
    elif second_value < 0:
        print(f"x = {point}: Local Maximum")
    else:
        print(f"x = {point}: Test Inconclusive")
# Out:
# First Derivative:
# 3*x**2 - 12*x + 9
#
# Critical Points Analysis:
# x = 1: Local Maximum
# x = 3: Local Minimum
